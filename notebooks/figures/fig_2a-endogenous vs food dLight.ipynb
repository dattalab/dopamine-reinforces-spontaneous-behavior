# %%
import toml
import joblib
import seaborn as sns
import matplotlib.pyplot as plt

from os.path import join
from rl_analysis import ANALYSIS_CONFIG
from rl_analysis.plotting import add_legend, save_factory, setup_plotting_env, COLORS, fg

# %%
with open(ANALYSIS_CONFIG, 'r') as f:
    config = toml.load(f)

saver = save_factory(join(config['figures']['dir_wg'], 'fig-01'), tight_layout=False)

setup_plotting_env()

# %% [markdown]
# ## Add food peaks

# %%
food_peaks = joblib.load('/home/wg41/reinforcement_data/public-dataset/dlight-food-peaks.p')

# %%
list(food_peaks)
# Out:
# ['approach_da+vel',
#  'approach_spont_da',
#  'approach_and_eat_da+vel',
#  'approach_and_eat_spont_da',
#  'eat_da+vel',
#  'eat_spont_da']

# %%
food_peaks['eat_da+vel'].query('time == 0')['trace'].agg(['mean', 'std', 'count', 'max'])
# Out:
# mean      2.364895
# std       0.917223
# count    10.000000
# max       3.942242
# Name: trace, dtype: float64

# %%
food_peaks['eat_spont_da'].query('time == 0')['trace'].agg(['mean', 'std', 'count', 'max'])
# Out:
# mean        2.121785
# std         0.801698
# count    5247.000000
# max         9.385931
# Name: trace, dtype: float64

# %%
fig = fg(1, 0.75)
ax = sns.histplot(
    food_peaks['eat_spont_da'].query('time == 0')['trace'],
    fill=False,
    stat="probability",
    element="step",
    label="Spontaneous",
    color=COLORS['green'],
    binwidth=0.6,
    linewidth=1
)

sns.histplot(
    food_peaks['eat_da+vel'].query('time == 0')['trace'],
    fill=False,
    stat="probability",
    element="step",
    label="Food reward",
    color='k',
    binwidth=0.6,
    linewidth=1
)
sns.despine()
plt.axvline(1.5, color='k', linestyle='--', linewidth=1)
plt.xlabel("Peak dLight dF/F0 (z)")
add_legend(ax)
plt.xticks([0, 10])
plt.xlim(0, 10)
plt.yticks([0, 0.6])
plt.ylim(0, 0.6)
saver(fig, 'spont-dlight-vs-food-peaks');

# %% [markdown]
# ## Plot peak-aligned food and spontaneous waveform

# %%
fig = fg(1, 0.75)
ax = sns.lineplot(
    data=food_peaks["eat_spont_da"],
    x="time",
    y="trace",
    errorbar=('ci', 68),
    color=COLORS['green'],
    label="Spontaneous",
)
sns.lineplot(
    data=food_peaks["eat_da+vel"], x="time", y="trace", errorbar=('ci', 68), color='k', label="Food reward"
)
plt.xlim(-1.5, 1.5)
plt.xticks([-1.5, 0, 1.5])
print(plt.ylim())
plt.yticks([-1, 0, 3])
plt.ylim(-1, 3)
add_legend(ax)
plt.ylabel("dF/F0 (z)")
plt.xlabel("Time aligned to peak (s)")
sns.despine()
saver(fig, "spont-dlight-vs-food-waveforms");
# Out:
# (-0.9761436607316702, 2.800601108485464)

# %% [markdown]
# ## Plot velocity

# %%
_df = food_peaks['eat_da+vel']
_df['velocity'] *= 30

# %%
fig = fg(1, 0.75)
ax = sns.lineplot(
    data=_df, x="time", y="velocity", errorbar=("ci", 68), color="k", err_kws=dict(linewidth=0)
)
plt.xlim(-1.5, 1.5)
plt.xticks([-1.5, 0, 1.5])
print(plt.ylim())
plt.yticks([0, 120])
plt.ylim(0, 120)
plt.ylabel("Velocity (mm/s)")
plt.xlabel("Time aligned to peak (s)")
sns.despine()
saver(fig, "velocity-aligned-to-eating");
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# (-3.640974432468413, 164.01492561006543)
